# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.data_prep import load_raw, clean, save_clean

df = clean(load_raw())           # load from data/ and clean
output_path = save_clean(df)     # writes to data/online_retail_clean.csv

df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 805549 entries, 0 to 805548
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Invoice       805549 non-null  object
#  1   StockCode     805549 non-null  object
#  2   Description   805549 non-null  object
#  3   Quantity      805549 non-null  int64
#  4   InvoiceDate   805549 non-null  datetime64[ns]
#  5   Price         805549 non-null  float64
#  6   Customer ID   805549 non-null  int64
#  7   Country       805549 non-null  object
#  8   TotalPrice    805549 non-null  float64
#  9   InvoiceYear   805549 non-null  int32
#  10  InvoiceMonth  805549 non-null  int32
#  11  YearMonth     805549 non-null  period[M]
#  12  InvoiceWeek   805549 non-null  UInt32
#  13  InvoiceDay    805549 non-null  object
# dtypes: UInt32(1), datetime64[ns](1), float64(2), int32(2), int64(2), object(5), period[M](1)
# memory usage: 77.6+ MB
# ...
