# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.data_prep import load_raw, clean, save_clean

df = clean(load_raw())           # load from data/ and clean
output_path = save_clean(df)     # writes to data/online_retail_clean.csv

df.head()
df.info()
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 6
#       2 from pathlib import Path
#       4 sys.path.append(str(Path.cwd().parent / "src"))
# ----> 6 from src.data_prep import load_raw, clean, save_clean
#       8 df = clean(load_raw())           # load from data/ and clean
#       9 output_path = save_clean(df)     # writes to data/online_retail_clean.csv
#
# ModuleNotFoundError: No module named 'src'
